# %%
import sys
import os
import numpy as np
import pandas as pd
import andi
import dcgan
from sklearn import preprocessing
from andi import diffusion_models
import matplotlib.pyplot as plt
np.random.seed(2021)

import dcgan

# %% [markdown]
# DATA FOR GAN

# %%
num_of_each_cls = 5
dimensions = 2
length = 999
AD = andi.andi_datasets()
diff_mod = diffusion_models.twoD()
tracks = []
labels = []

dataset = AD.create_dataset(T = length, N = num_of_each_cls, exponents = [0.5, 0.9, 1.4, 1.8], models = [2], dimension = 2)

for i in range(num_of_each_cls*4):
    tracks.append(preprocessing.maxabs_scale(dataset[i, 2:].reshape(2,999).T))
tracks = np.array(tracks)

np.save('./dataset/andi_train_tracks', tracks)

# %% [markdown]
# DATA FOR CNN TEST

# %%
num_of_each_cls = 1000
dimensions = 2
length = 999
AD = andi.andi_datasets()
diff_mod = diffusion_models.twoD()
tracks = []
labels = []

dataset = AD.create_dataset(T = length, N = num_of_each_cls, exponents = [0.5, 0.9, 1.4, 1.8], models = [2], dimension = 2)

for i in range(num_of_each_cls*4):
    tracks.append(preprocessing.maxabs_scale(dataset[i, 2:].reshape(2,999).T))
tracks = np.array(tracks)

for i in range(4):
    labels.append(np.zeros(num_of_each_cls) + i)
labels = np.array(labels).reshape(num_of_each_cls*4)

np.save('./dataset/andi_test_tracks', tracks)
np.save('./dataset/andi_test_labels', labels)
# Out:
# c:\users\15051\appdata\local\programs\python\python38\lib\site-packages\fbm\fbm.py:171: UserWarning: Combination of increments n and Hurst value H invalid for Davies-Harte method. Reverting to Hosking method. Occurs when n is small and Hurst is close to 1.
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-eb4df6853e25> in <module>
#       7 labels = []
#       8
# ----> 9 dataset = AD.create_dataset(T = length, N = num_of_each_cls, exponents = [0.5, 0.9, 1.4, 1.8], models = [2], dimension = 2)
#      10
#      11 for i in range(num_of_each_cls*4):
#
# c:\users\15051\appdata\local\programs\python\python38\lib\site-packages\andi\andi.py in create_dataset(self, T, N, exponents, models, dimension, save_trajectories, load_trajectories, path, N_save, t_save)
#     167
#     168         else:
# --> 169             data_models = self.create_trajectories(T = T,
#     170                                                    exponents = exponents,
#     171                                                    dimension = self.dimension,
#
# c:\users\15051\appdata\local\programs\python\python38\lib\site-packages\andi\andi.py in create_trajectories(self, T, exponents, dimension, models_name, models_func, n_per_class)
#     324                 data = np.zeros((n, self.dimension*T))
#     325                 for i in range(n):
# --> 326                     data[i, :] = func(T, exp)
#     327
#     328                 data = self.label_trajectories(trajs = data, model_name = name, exponent = exp)
#
# c:\users\15051\appdata\local\programs\python\python38\lib\site-packages\andi\diffusion_models.py in fbm(self, T, alpha)
#     175             # Defin Hurst exponent
#     176             H = alpha*0.5
# --> 177             return np.concatenate((fbm.fbm(int(T-1), H), fbm.fbm(int(T-1), H)))
#     178
#     179
#
# c:\users\15051\appdata\local\programs\python\python38\lib\site-packages\fbm\fbm.py in fbm(n, hurst, length, method)
#     268     """One off sample of fBm."""
#     269     f = FBM(n, hurst, length, method)
# --> 270     return f.fbm()
#     271
#     272
#
# c:\users\15051\appdata\local\programs\python\python38\lib\site-packages\fbm\fbm.py in fbm(self)
#     108     def fbm(self):
#     109         """Sample the fractional Brownian motion."""
# --> 110         return np.insert(self.fgn().cumsum(), [0], 0)
#     111
#     112     def fgn(self):
#
# c:\users\15051\appdata\local\programs\python\python38\lib\site-packages\fbm\fbm.py in fgn(self)
#     119             return gn * scale
#     120         else:
# --> 121             fgn = self._fgn(gn)
#     122
#     123         # Scale to interval [0, L]
#
# c:\users\15051\appdata\local\programs\python\python38\lib\site-packages\fbm\fbm.py in _daviesharte(self, gn)
#     178             # Don"t need to store eigenvals anymore.
#     179             self._eigenvals = None
# --> 180             return self._hosking(gn)
#     181
#     182         # Generate second sequence of i.i.d. standard normals
#
# c:\users\15051\appdata\local\programs\python\python38\lib\site-packages\fbm\fbm.py in _hosking(self, gn)
#     253             for j in range(i - 1):
#     254                 psi[j] = phi[j]
# --> 255                 phi[i - 1] -= psi[j] * self._cov[i - j - 1]
#     256             phi[i - 1] /= v
#     257             for j in range(i - 1):
#
# KeyboardInterrupt:

# %%
dcgan.plt_tracks(tracks[15:20])
